# %%
! conda install nb_conda_kernels ipywidgets -c conda-forge -n base -y
! conda env create -f environment.yml
! conda env update -f environment.yml
# Out:
# CondaValueError: prefix already exists: /u/n/p/npalumbo/anaconda3/envs/distillation
#
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.0
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# Downloading and Extracting Packages
# matplotlib-3.3.3     | 6 KB      | ##################################### | 100%
# expat-2.2.9          | 191 KB    | ##################################### | 100%
# libiconv-1.16        | 1.4 MB    | ##################################### | 100%
# pcre-8.44            | 261 KB    | ##################################### | 100%
# libxml2-2.9.9        | 1.3 MB    | ##################################### | 100%
# fontconfig-2.13.1    | 327 KB    | ##################################### | 100%
# pip-20.3.1           | 1.1 MB    | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# matplotlib-base-3.3. | 6.7 MB    | ##################################### | 100%
# icu-58.2             | 22.6 MB   | ##################################### | 100%
# xorg-libxdmcp-1.1.3  | 18 KB     | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# libuuid-2.32.1       | 26 KB     | ##################################### | 100%
# cycler-0.10.0        | 9 KB      | ##################################### | 100%
# kiwisolver-1.3.1     | 86 KB     | ##################################### | 100%
# pandas-1.1.4         | 10.9 MB   | ##################################### | 100%
# ipykernel-5.3.4      | 166 KB    | ##################################### | 100%
# ca-certificates-2020 | 137 KB    | ##################################### | 100%
# libxcb-1.13          | 396 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate distillation
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
import torch
import torchvision
import numpy as np
import pandas as pd
import PIL
from time import time
from torch import nn, optim
from torchvision import transforms
from variable_width_resnet import resnet10vw
import json
from math import ceil

# %%
data_dir = "/nobackup/data/celebA"

label = "Blond_Hair"
spurious = "Male"

batch_size_teacher = 1024
batch_size_student = 2048
max_workers = 64
epochs = 50
teacher_width = 96
student_width = 8
augmented=True
augment_student=augmented
augment_teacher=augmented
temperature = 3.

device = torch.device("cuda:0") if torch.has_cuda else torch.device("cpu")

# %%
attributes = pd.read_csv(f"{data_dir}/list_attr_celeba.csv")
partitions = pd.read_csv(f"{data_dir}/list_eval_partition.csv")

# %%
def ReweightedLoss(group_fractions):
    cross_entropy = torch.nn.CrossEntropyLoss(reduction="none")
    
    def loss(logits, labels, groups):
        losses = cross_entropy(logits, labels)
        
        for group_id in range(group_fractions.shape[0]):
            losses[groups == group_id] /= group_fractions[group_id]
            
        return losses.mean()
        
    return loss

def DistillationLossReweighted(temperature, group_fractions):
    cross_entropy = torch.nn.CrossEntropyLoss(reduction="none")
        
    def loss(student_logits, teacher_logits, target, groups):
        last_dim = len(student_logits.shape) - 1
        
        p_t = nn.functional.softmax(teacher_logits/temperature, dim=last_dim)
        log_p_s = nn.functional.log_softmax(student_logits/temperature, dim=last_dim)
        
        losses = cross_entropy(student_logits, target) - (p_t * log_p_s).sum(dim=last_dim)
        
        for group_id in range(group_fractions.shape[0]):
            losses[groups == group_id] /= group_fractions[group_id]
        
        return losses.mean()
    
    return loss

# %%
def evaluate(model, loader, name=""):
    total_correct = torch.zeros(2,2)
    total_items = torch.zeros(2,2)
    training = model.training
    model.eval()
    
    with torch.no_grad():
        for data, attrs in iter(loader):
            target = attrs[..., 1]
            data, target = data.to(device), target.to(device)
            
            out = model(data)
            
            correct = (out.argmax(axis=1) == target).to("cpu")
            batch_size = correct.shape[0]
            
            for batch_idx in range(batch_size):
                bin_idx = list(attrs[batch_idx])
                
                total_correct[bin_idx] += correct[batch_idx]
                total_items[bin_idx] += 1
                
    model.train(training)
                
    group_accuracies = total_correct / total_items
                
    print(f"{name} set results:")
    print(f"Average case accuracy: {total_correct.sum()}/{total_items.sum()}={total_correct.sum()/total_items.sum()}\n")
    
    status = lambda x: " not " if x == 0 else " "
    
    def from_flat_idx(x):
        idx0 = 1 if x > 1 else 0
        idx1 = x - 2 * idx0
        
        return idx0, idx1
    
    worst = from_flat_idx(group_accuracies.argmin())
    
    print(f"Worst case group:{status(worst[0])}{spurious.lower()} [spurious] and{status(worst[1])}{label.lower()} [target]")
    print(f"Worst case accuracy: {total_correct[worst]}/{total_items[worst]}={group_accuracies[worst]}\n")
    
    return {
        "worst": group_accuracies[worst].item(),
        "average": (total_correct.sum()/total_items.sum()).item()
    }

# %%
class CelebAFairnessDataset(torchvision.datasets.VisionDataset):
    def __init__(self, 
                 attribute_df=attributes, 
                 partition_df=partitions,
                 split="train", 
                 augment=False,
                 spurious=spurious, 
                 label=label,
                 root=f"{data_dir}/img_align_celeba/"):           
        partition_id = 0 if split == "train" else 1 if split == "valid" else 2
        
        df = attribute_df[partition_df.partition == partition_id]
        
        self.files = root + df.image_id.values
        
        self.attrs = df[[spurious, label]].values
        
        # Negative cases are labeled 0 instead of -1
        self.attrs[self.attrs < 0] = 0
        
        # Overparameterization paper transform:
        train = split == "train"
        orig_w = 178
        orig_h = 218
        orig_min_dim = min(orig_w, orig_h)
        target_resolution = (224, 224)

        if not augment:
            self.transform = transforms.Compose([
                transforms.CenterCrop(orig_min_dim),
                transforms.Resize(target_resolution),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ])
        else:
            # Orig aspect ratio is 0.81, so we don't squish it in that direction any more
            self.transform = transforms.Compose([
                transforms.RandomResizedCrop(
                    target_resolution,
                    scale=(0.7, 1.0),
                    ratio=(1.0, 1.3333333333333333),
                    interpolation=2),
                transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ])
        
    def __getitem__(self, idx):
        img = PIL.Image.open(self.files[idx])
        attrs = self.attrs[idx]
        
        return [
            self.transform(img),
            torch.Tensor(attrs).long()
        ]
        
    def __len__(self):
        return self.files.shape[0]

# %%
training = CelebAFairnessDataset(augment=augment_teacher)

teacher_train_loader = torch.utils.data.DataLoader(training,
                                           num_workers=max_workers,
                                           batch_size=batch_size_teacher,
                                           shuffle=True,
                                           pin_memory=True)
student_train_loader = torch.utils.data.DataLoader(CelebAFairnessDataset(augment=augment_student),
                                           num_workers=max_workers,
                                           batch_size=batch_size_student,
                                           shuffle=True,
                                           pin_memory=True)
validation_loader = torch.utils.data.DataLoader(CelebAFairnessDataset(split="valid"),
                                           num_workers=max_workers,
                                           batch_size=batch_size_student,
                                           shuffle=False,
                                           pin_memory=True)
test_loader = torch.utils.data.DataLoader(CelebAFairnessDataset(split="test"),
                                           num_workers=max_workers,
                                           batch_size=batch_size_student,
                                           shuffle=False,
                                           pin_memory=True)

test_results = lambda model: evaluate(model, test_loader, name="Test")
valid_results = lambda model: evaluate(model, validation_loader, name="Validation")

attrs = torch.Tensor(training.attrs).long()
group_fractions = torch.bincount(attrs[..., 0] + attrs[...,1]*2).float()
group_fractions /= group_fractions.sum()

# %%
teacher = nn.DataParallel(resnet10vw(teacher_width, num_classes=2)).to(device)
student =  nn.DataParallel(resnet10vw(student_width, num_classes=2)).to(device)
student_no_distillation = nn.DataParallel(resnet10vw(student_width, num_classes=2)).to(device)

optimizer_teacher = optim.Adam(teacher.parameters())
optimizer_student = optim.Adam(student.parameters())
optimizer_no_distillation = optim.Adam(student_no_distillation.parameters())

# %%
teacher_test_results = []
teacher_validation_results  = []

# Train teacher   
print("\nTraining teacher model")

criterion = ReweightedLoss(group_fractions)

teacher.train()

for epoch in range(epochs):
    epoch_loss = 0.
    start = time()

    for data, attrs in iter(teacher_train_loader):
        target = attrs[..., 1] # Spurious label is index 0
        groups = attrs[..., 0] + attrs[..., 1] * 2

        data, target = data.to(device), target.to(device)

        out = teacher(data)
        loss = criterion(out, target, groups)
        loss.backward()

        epoch_loss += loss.item()

        optimizer_teacher.step()      
        optimizer_teacher.zero_grad()

    end = time()
    teacher_test_results.append(test_results(teacher))
    teacher_validation_results.append(valid_results(teacher))

    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}: total loss {epoch_loss} in {end - start} seconds")

    start_epoch = -1

# Train student
print("\nTraining student models")

criterion = DistillationLossReweighted(temperature, group_fractions)
criterion_no_distillation = ReweightedLoss(group_fractions)

teacher.eval()
student.train()
student_no_distillation.train()

student_test_results = []
student_validation_results = []
student_no_distillation_test_results = []
student_no_distillation_validation_results  = []

for epoch in range(epochs):
    epoch_loss = 0.
    epoch_loss_no_distillation = 0.
    start = time()

    for data, attrs in iter(student_train_loader):
        target = attrs[..., 1] # Spurious label is index 0
        groups = attrs[..., 0] + attrs[..., 1] * 2

        data, target = data.to(device), target.to(device)

        out_student = student(data)

        with torch.no_grad():
            out_teacher = teacher(data)

        loss = criterion(out_student, out_teacher, target, groups)
        loss.backward()

        epoch_loss += loss.item()

        optimizer_student.step()
        optimizer_student.zero_grad()

        out = student_no_distillation(data)
        loss = criterion_no_distillation(out, target, groups)
        loss.backward()

        epoch_loss_no_distillation += loss.item()

        optimizer_no_distillation.step()      
        optimizer_no_distillation.zero_grad()

    end = time()
    student_test_results.append(test_results(student))
    student_validation_results.append(valid_results(student))
    student_no_distillation_test_results.append(test_results(student_no_distillation))
    student_no_distillation_validation_results.append(valid_results(student_no_distillation))

    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}: total loss {epoch_loss} (with distillation) {epoch_loss_no_distillation} (without distillation) in {end - start} seconds")

results = {
    "teacher_size": teacher_width,
    "student_size": student_width,
    "teacher_augmentation": augment_teacher,
    "student_augmentation": augment_student,
    "teacher_test": teacher_test_results,
    "student_test": student_test_results,
    "student_no_distillation_test": student_no_distillation_test_results,
    "teacher_validation": teacher_validation_results,
    "student_validation": student_validation_results,
    "student_no_distillation_validation": student_no_distillation_validation_results,
}

with open(f"{teacher_width}-to-{student_width}{'-augmented' if augmented else ''}.json", "w") as f:
    json.dump(results, f)
# Out:
# Training teacher model
# Test set results:
# Average case accuracy: 16711.0/19962.0=0.8371405601501465
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/180.0=0.8055555820465088
#
# Validation set results:
# Average case accuracy: 16253.0/19867.0=0.8180903196334839
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6496.0/8535.0=0.7611013650894165
#
# Test set results:
# Average case accuracy: 17230.0/19962.0=0.8631399869918823
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8206.0/9767.0=0.8401761054992676
#
# Validation set results:
# Average case accuracy: 16794.0/19867.0=0.8453214168548584
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6833.0/8535.0=0.8005858063697815
#
# Test set results:
# Average case accuracy: 17666.0/19962.0=0.8849814534187317
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6599.0/7535.0=0.8757796883583069
#
# Validation set results:
# Average case accuracy: 17279.0/19867.0=0.8697337508201599
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7155.0/8535.0=0.8383128046989441
#
# Test set results:
# Average case accuracy: 18156.0/19962.0=0.9095280766487122
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 17862.0/19867.0=0.8990788459777832
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/182.0=0.8681318759918213
#
# Test set results:
# Average case accuracy: 18499.0/19962.0=0.9267107248306274
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 141.0/180.0=0.7833333611488342
#
# Validation set results:
# Average case accuracy: 18268.0/19867.0=0.9195147752761841
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 148.0/182.0=0.8131868243217468
#
# Test set results:
# Average case accuracy: 18670.0/19962.0=0.9352770447731018
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 134.0/180.0=0.7444444298744202
#
# Validation set results:
# Average case accuracy: 18386.0/19867.0=0.9254542589187622
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/182.0=0.807692289352417
#
# Test set results:
# Average case accuracy: 18653.0/19962.0=0.934425413608551
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18406.0/19867.0=0.9264609813690186
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/182.0=0.8021978139877319
#
# Test set results:
# Average case accuracy: 18350.0/19962.0=0.9192465543746948
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 148.0/180.0=0.8222222328186035
#
# Validation set results:
# Average case accuracy: 18052.0/19867.0=0.9086424708366394
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/182.0=0.807692289352417
#
# Test set results:
# Average case accuracy: 17381.0/19962.0=0.8707043528556824
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8307.0/9767.0=0.8505170345306396
#
# Validation set results:
# Average case accuracy: 17018.0/19867.0=0.8565963506698608
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6970.0/8535.0=0.816637396812439
#
# Test set results:
# Average case accuracy: 18292.0/19962.0=0.9163410663604736
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/180.0=0.8666666746139526
#
# Validation set results:
# Average case accuracy: 17986.0/19867.0=0.905320405960083
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Epoch 10: total loss 148.95803898572922 in 79.64242100715637 seconds
# Test set results:
# Average case accuracy: 18375.0/19962.0=0.9204989671707153
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/180.0=0.8722222447395325
#
# Validation set results:
# Average case accuracy: 18113.0/19867.0=0.9117128849029541
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7600.0/8535.0=0.8904510736465454
#
# Test set results:
# Average case accuracy: 18624.0/19962.0=0.9329726696014404
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 122.0/180.0=0.6777777671813965
#
# Validation set results:
# Average case accuracy: 18389.0/19867.0=0.925605297088623
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 132.0/182.0=0.7252747416496277
#
# Test set results:
# Average case accuracy: 17884.0/19962.0=0.8959022164344788
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8635.0/9767.0=0.884099543094635
#
# Validation set results:
# Average case accuracy: 17534.0/19867.0=0.8825690746307373
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7336.0/8535.0=0.8595196008682251
#
# Test set results:
# Average case accuracy: 18210.0/19962.0=0.9122332334518433
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/180.0=0.8500000238418579
#
# Validation set results:
# Average case accuracy: 17893.0/19867.0=0.9006392359733582
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7521.0/8535.0=0.881195068359375
#
# Test set results:
# Average case accuracy: 18151.0/19962.0=0.909277617931366
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/180.0=0.8888888955116272
#
# Validation set results:
# Average case accuracy: 17888.0/19867.0=0.9003875851631165
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7481.0/8535.0=0.8765084743499756
#
# Test set results:
# Average case accuracy: 18077.0/19962.0=0.9055705666542053
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8680.0/9767.0=0.8887068629264832
#
# Validation set results:
# Average case accuracy: 17804.0/19867.0=0.8961594700813293
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7377.0/8535.0=0.8643233776092529
#
# Test set results:
# Average case accuracy: 17891.0/19962.0=0.8962528705596924
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8607.0/9767.0=0.881232738494873
#
# Validation set results:
# Average case accuracy: 17592.0/19867.0=0.8854885101318359
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7282.0/8535.0=0.8531927466392517
#
# Test set results:
# Average case accuracy: 18049.0/19962.0=0.904167890548706
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17690.0/19867.0=0.8904213309288025
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7246.0/8535.0=0.8489748239517212
#
# Test set results:
# Average case accuracy: 18054.0/19962.0=0.904418408870697
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/180.0=0.8833333253860474
#
# Validation set results:
# Average case accuracy: 17791.0/19867.0=0.8955051302909851
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7390.0/8535.0=0.8658465147018433
#
# Test set results:
# Average case accuracy: 18695.0/19962.0=0.9365293979644775
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 138.0/180.0=0.7666666507720947
#
# Validation set results:
# Average case accuracy: 18450.0/19867.0=0.9286757111549377
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/182.0=0.8736263513565063
#
# Epoch 20: total loss 130.36506697535515 in 82.66170239448547 seconds
# Test set results:
# Average case accuracy: 18541.0/19962.0=0.9288147687911987
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/180.0=0.8388888835906982
#
# Validation set results:
# Average case accuracy: 18285.0/19867.0=0.9203704595565796
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7707.0/8535.0=0.9029877185821533
#
# Test set results:
# Average case accuracy: 18609.0/19962.0=0.9322212338447571
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/180.0=0.8444444537162781
#
# Validation set results:
# Average case accuracy: 18361.0/19867.0=0.9241958856582642
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 166.0/182.0=0.9120879173278809
#
# Test set results:
# Average case accuracy: 18308.0/19962.0=0.9171425700187683
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8860.0/9767.0=0.9071362614631653
#
# Validation set results:
# Average case accuracy: 18025.0/19867.0=0.9072834253311157
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7560.0/8535.0=0.885764479637146
#
# Test set results:
# Average case accuracy: 18719.0/19962.0=0.9377316832542419
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 18505.0/19867.0=0.9314441084861755
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 161.0/182.0=0.8846153616905212
#
# Test set results:
# Average case accuracy: 17785.0/19962.0=0.8909428119659424
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8468.0/9767.0=0.8670011162757874
#
# Validation set results:
# Average case accuracy: 17443.0/19867.0=0.8779886364936829
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7114.0/8535.0=0.833509087562561
#
# Test set results:
# Average case accuracy: 17646.0/19962.0=0.8839795589447021
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8388.0/9767.0=0.858810305595398
#
# Validation set results:
# Average case accuracy: 17246.0/19867.0=0.8680726885795593
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7006.0/8535.0=0.8208553194999695
#
# Test set results:
# Average case accuracy: 16762.0/19962.0=0.839695394039154
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6122.0/7535.0=0.8124751448631287
#
# Validation set results:
# Average case accuracy: 16352.0/19867.0=0.8230734467506409
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6693.0/8535.0=0.7841827869415283
#
# Test set results:
# Average case accuracy: 18442.0/19962.0=0.9238553047180176
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/180.0=0.8611111044883728
#
# Validation set results:
# Average case accuracy: 18129.0/19867.0=0.9125182628631592
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7613.0/8535.0=0.8919742107391357
#
# Test set results:
# Average case accuracy: 18693.0/19962.0=0.9364292025566101
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 143.0/180.0=0.7944444417953491
#
# Validation set results:
# Average case accuracy: 18422.0/19867.0=0.9272662997245789
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/182.0=0.8681318759918213
#
# Test set results:
# Average case accuracy: 18827.0/19962.0=0.9431419968605042
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 138.0/180.0=0.7666666507720947
#
# Validation set results:
# Average case accuracy: 18661.0/19867.0=0.939296305179596
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 149.0/182.0=0.8186812996864319
#
# Epoch 30: total loss 112.27240177989006 in 83.32945370674133 seconds
# Test set results:
# Average case accuracy: 18741.0/19962.0=0.9388337731361389
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 133.0/180.0=0.7388888597488403
#
# Validation set results:
# Average case accuracy: 18500.0/19867.0=0.9311924576759338
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/182.0=0.7967032790184021
#
# Test set results:
# Average case accuracy: 17324.0/19962.0=0.8678489327430725
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8252.0/9767.0=0.8448858261108398
#
# Validation set results:
# Average case accuracy: 16987.0/19867.0=0.8550359606742859
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6963.0/8535.0=0.8158172369003296
#
# Test set results:
# Average case accuracy: 18566.0/19962.0=0.9300671219825745
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/180.0=0.8500000238418579
#
# Validation set results:
# Average case accuracy: 18278.0/19867.0=0.9200181365013123
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 162.0/182.0=0.8901098966598511
#
# Test set results:
# Average case accuracy: 18496.0/19962.0=0.9265604615211487
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 154.0/180.0=0.855555534362793
#
# Validation set results:
# Average case accuracy: 18293.0/19867.0=0.9207731485366821
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7800.0/8535.0=0.9138839840888977
#
# Test set results:
# Average case accuracy: 18582.0/19962.0=0.9308686256408691
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/180.0=0.8055555820465088
#
# Validation set results:
# Average case accuracy: 18310.0/19867.0=0.9216288328170776
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 162.0/182.0=0.8901098966598511
#
# Test set results:
# Average case accuracy: 18703.0/19962.0=0.9369301795959473
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18506.0/19867.0=0.931494414806366
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 162.0/182.0=0.8901098966598511
#
# Test set results:
# Average case accuracy: 18469.0/19962.0=0.9252079129219055
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/180.0=0.8444444537162781
#
# Validation set results:
# Average case accuracy: 18247.0/19867.0=0.9184577465057373
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7562.0/8535.0=0.8859988451004028
#
# Test set results:
# Average case accuracy: 18696.0/19962.0=0.9365795254707336
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 18495.0/19867.0=0.9309407472610474
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 164.0/182.0=0.901098906993866
#
# Test set results:
# Average case accuracy: 18777.0/19962.0=0.9406372308731079
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 137.0/180.0=0.7611111402511597
#
# Validation set results:
# Average case accuracy: 18569.0/19867.0=0.9346655011177063
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 18524.0/19962.0=0.927963137626648
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 149.0/180.0=0.8277778029441833
#
# Validation set results:
# Average case accuracy: 18278.0/19867.0=0.9200181365013123
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/182.0=0.8791208863258362
#
# Epoch 40: total loss 98.87690761685371 in 77.99951839447021 seconds
# Test set results:
# Average case accuracy: 18662.0/19962.0=0.9348762631416321
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/180.0=0.8388888835906982
#
# Validation set results:
# Average case accuracy: 18386.0/19867.0=0.9254542589187622
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7666.0/8535.0=0.8981839418411255
#
# Test set results:
# Average case accuracy: 18434.0/19962.0=0.9234545826911926
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/180.0=0.8666666746139526
#
# Validation set results:
# Average case accuracy: 18202.0/19867.0=0.9161927103996277
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7533.0/8535.0=0.8826010823249817
#
# Test set results:
# Average case accuracy: 18279.0/19962.0=0.9156898260116577
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 133.0/180.0=0.7388888597488403
#
# Validation set results:
# Average case accuracy: 18067.0/19867.0=0.9093974828720093
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/182.0=0.8296703100204468
#
# Test set results:
# Average case accuracy: 18646.0/19962.0=0.9340747594833374
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 136.0/180.0=0.7555555701255798
#
# Validation set results:
# Average case accuracy: 18382.0/19867.0=0.9252529144287109
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/182.0=0.8791208863258362
#
# Test set results:
# Average case accuracy: 18395.0/19962.0=0.9215008616447449
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/180.0=0.8611111044883728
#
# Validation set results:
# Average case accuracy: 18179.0/19867.0=0.9150350093841553
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7453.0/8535.0=0.8732278943061829
#
# Test set results:
# Average case accuracy: 18754.0/19962.0=0.9394850134849548
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18476.0/19867.0=0.9299843907356262
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 18838.0/19962.0=0.9436930418014526
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 135.0/180.0=0.75
#
# Validation set results:
# Average case accuracy: 18603.0/19867.0=0.9363769292831421
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/182.0=0.807692289352417
#
# Test set results:
# Average case accuracy: 18620.0/19962.0=0.9327722787857056
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 141.0/180.0=0.7833333611488342
#
# Validation set results:
# Average case accuracy: 18393.0/19867.0=0.9258066415786743
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Test set results:
# Average case accuracy: 18922.0/19962.0=0.9479010105133057
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 124.0/180.0=0.6888889074325562
#
# Validation set results:
# Average case accuracy: 18753.0/19867.0=0.9439271092414856
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 138.0/182.0=0.7582417726516724
#
# Test set results:
# Average case accuracy: 18730.0/19962.0=0.9382827281951904
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 18536.0/19867.0=0.9330044984817505
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 161.0/182.0=0.8846153616905212
#
# Epoch 50: total loss 85.25860825181007 in 72.44894862174988 seconds
#
# Training student models
# Test set results:
# Average case accuracy: 17724.0/19962.0=0.8878870010375977
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 120.0/180.0=0.6666666865348816
#
# Validation set results:
# Average case accuracy: 17346.0/19867.0=0.8731061816215515
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 140.0/182.0=0.7692307829856873
#
# Test set results:
# Average case accuracy: 16896.0/19962.0=0.8464081883430481
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6159.0/7535.0=0.8173855543136597
#
# Validation set results:
# Average case accuracy: 16453.0/19867.0=0.8281572461128235
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6882.0/8535.0=0.8063268661499023
#
# Test set results:
# Average case accuracy: 17940.0/19962.0=0.8987075686454773
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 132.0/180.0=0.7333333492279053
#
# Validation set results:
# Average case accuracy: 17620.0/19867.0=0.88689786195755
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/182.0=0.8296703100204468
#
# Test set results:
# Average case accuracy: 17339.0/19962.0=0.8686003684997559
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 16930.0/19867.0=0.8521668910980225
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7052.0/8535.0=0.8262448906898499
#
# Test set results:
# Average case accuracy: 16194.0/19962.0=0.8112413883209229
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 5925.0/7535.0=0.7863304615020752
#
# Validation set results:
# Average case accuracy: 15779.0/19867.0=0.794231653213501
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6308.0/8535.0=0.7390744090080261
#
# Test set results:
# Average case accuracy: 15941.0/19962.0=0.7985672950744629
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 5784.0/7535.0=0.7676177620887756
#
# Validation set results:
# Average case accuracy: 15478.0/19867.0=0.779080867767334
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6227.0/8535.0=0.7295840382575989
#
# Test set results:
# Average case accuracy: 17257.0/19962.0=0.8644925355911255
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6410.0/7535.0=0.8506967425346375
#
# Validation set results:
# Average case accuracy: 16883.0/19867.0=0.8498011827468872
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6939.0/8535.0=0.813005268573761
#
# Test set results:
# Average case accuracy: 16498.0/19962.0=0.8264703154563904
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7842.0/9767.0=0.8029077649116516
#
# Validation set results:
# Average case accuracy: 16000.0/19867.0=0.8053556084632874
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6463.0/8535.0=0.7572349309921265
#
# Test set results:
# Average case accuracy: 18016.0/19962.0=0.9025147557258606
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/180.0=0.8444444537162781
#
# Validation set results:
# Average case accuracy: 17653.0/19867.0=0.8885589241981506
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7350.0/8535.0=0.8611599206924438
#
# Test set results:
# Average case accuracy: 16416.0/19962.0=0.82236248254776
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 5909.0/7535.0=0.7842070460319519
#
# Validation set results:
# Average case accuracy: 16015.0/19867.0=0.8061106204986572
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6604.0/8535.0=0.7737551331520081
#
# Test set results:
# Average case accuracy: 18348.0/19962.0=0.9191463589668274
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 137.0/180.0=0.7611111402511597
#
# Validation set results:
# Average case accuracy: 18073.0/19867.0=0.9096994996070862
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/182.0=0.8406593203544617
#
# Test set results:
# Average case accuracy: 17904.0/19962.0=0.8969041109085083
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/180.0=0.8055555820465088
#
# Validation set results:
# Average case accuracy: 17554.0/19867.0=0.8835757970809937
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7300.0/8535.0=0.8553016781806946
#
# Test set results:
# Average case accuracy: 18271.0/19962.0=0.915289044380188
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/180.0=0.8055555820465088
#
# Validation set results:
# Average case accuracy: 17999.0/19867.0=0.9059747457504272
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/182.0=0.8351648449897766
#
# Test set results:
# Average case accuracy: 18041.0/19962.0=0.9037671685218811
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 148.0/180.0=0.8222222328186035
#
# Validation set results:
# Average case accuracy: 17716.0/19867.0=0.891730010509491
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Test set results:
# Average case accuracy: 18010.0/19962.0=0.9022142291069031
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17718.0/19867.0=0.8918306827545166
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7501.0/8535.0=0.8788517713546753
#
# Test set results:
# Average case accuracy: 17243.0/19962.0=0.8637912273406982
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6361.0/7535.0=0.8441937565803528
#
# Validation set results:
# Average case accuracy: 16868.0/19867.0=0.8490461707115173
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6954.0/8535.0=0.8147627711296082
#
# Test set results:
# Average case accuracy: 18668.0/19962.0=0.9351768493652344
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 132.0/180.0=0.7333333492279053
#
# Validation set results:
# Average case accuracy: 18424.0/19867.0=0.9273669719696045
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 141.0/182.0=0.7747252583503723
#
# Test set results:
# Average case accuracy: 18242.0/19962.0=0.9138363003730774
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18000.0/19867.0=0.9060250520706177
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 148.0/182.0=0.8131868243217468
#
# Test set results:
# Average case accuracy: 18380.0/19962.0=0.9207494258880615
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18042.0/19867.0=0.9081391096115112
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 17993.0/19962.0=0.9013625979423523
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/180.0=0.8500000238418579
#
# Validation set results:
# Average case accuracy: 17670.0/19867.0=0.8894146084785461
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7393.0/8535.0=0.8661980032920837
#
# Epoch 10: total loss 214.6183750629425 (with distillation) 80.11248707771301 (without distillation) in 89.1323311328888 seconds
# Test set results:
# Average case accuracy: 17360.0/19962.0=0.8696523308753967
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6367.0/7535.0=0.844990074634552
#
# Validation set results:
# Average case accuracy: 17001.0/19867.0=0.8557406663894653
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7108.0/8535.0=0.8328061103820801
#
# Test set results:
# Average case accuracy: 17422.0/19962.0=0.8727582693099976
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6415.0/7535.0=0.8513603210449219
#
# Validation set results:
# Average case accuracy: 17122.0/19867.0=0.8618311882019043
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7188.0/8535.0=0.8421792387962341
#
# Test set results:
# Average case accuracy: 18654.0/19962.0=0.9344754815101624
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 137.0/180.0=0.7611111402511597
#
# Validation set results:
# Average case accuracy: 18422.0/19867.0=0.9272662997245789
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/182.0=0.807692289352417
#
# Test set results:
# Average case accuracy: 17721.0/19962.0=0.8877366781234741
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8549.0/9767.0=0.8752943873405457
#
# Validation set results:
# Average case accuracy: 17387.0/19867.0=0.8751698732376099
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7189.0/8535.0=0.8422964215278625
#
# Test set results:
# Average case accuracy: 18799.0/19962.0=0.9417393207550049
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 128.0/180.0=0.7111111283302307
#
# Validation set results:
# Average case accuracy: 18586.0/19867.0=0.9355212450027466
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 137.0/182.0=0.7527472376823425
#
# Test set results:
# Average case accuracy: 17981.0/19962.0=0.9007614254951477
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8683.0/9767.0=0.8890140056610107
#
# Validation set results:
# Average case accuracy: 17633.0/19867.0=0.8875522017478943
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7328.0/8535.0=0.8585823178291321
#
# Test set results:
# Average case accuracy: 17239.0/19962.0=0.8635908365249634
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6303.0/7535.0=0.8364963531494141
#
# Validation set results:
# Average case accuracy: 16873.0/19867.0=0.849297821521759
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6957.0/8535.0=0.8151142597198486
#
# Test set results:
# Average case accuracy: 17728.0/19962.0=0.8880873918533325
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8527.0/9767.0=0.8730418682098389
#
# Validation set results:
# Average case accuracy: 17370.0/19867.0=0.8743141889572144
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7153.0/8535.0=0.838078498840332
#
# Test set results:
# Average case accuracy: 16209.0/19962.0=0.8119927644729614
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 5915.0/7535.0=0.7850033044815063
#
# Validation set results:
# Average case accuracy: 15847.0/19867.0=0.797654390335083
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6336.0/8535.0=0.7423549890518188
#
# Test set results:
# Average case accuracy: 18263.0/19962.0=0.9148882627487183
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/180.0=0.8666666746139526
#
# Validation set results:
# Average case accuracy: 17923.0/19867.0=0.9021493196487427
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/182.0=0.8736263513565063
#
# Test set results:
# Average case accuracy: 18298.0/19962.0=0.9166415929794312
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 161.0/180.0=0.894444465637207
#
# Validation set results:
# Average case accuracy: 18022.0/19867.0=0.9071324467658997
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7644.0/8535.0=0.8956063389778137
#
# Test set results:
# Average case accuracy: 18092.0/19962.0=0.9063220024108887
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/180.0=0.8888888955116272
#
# Validation set results:
# Average case accuracy: 17776.0/19867.0=0.8947500586509705
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7438.0/8535.0=0.8714703917503357
#
# Test set results:
# Average case accuracy: 17760.0/19962.0=0.8896903991699219
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6561.0/7535.0=0.8707365393638611
#
# Validation set results:
# Average case accuracy: 17390.0/19867.0=0.8753209114074707
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7266.0/8535.0=0.8513181209564209
#
# Test set results:
# Average case accuracy: 17176.0/19962.0=0.8604348301887512
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6291.0/7535.0=0.8349037766456604
#
# Validation set results:
# Average case accuracy: 16807.0/19867.0=0.8459757566452026
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6964.0/8535.0=0.8159343600273132
#
# Test set results:
# Average case accuracy: 18308.0/19962.0=0.9171425700187683
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 154.0/180.0=0.855555534362793
#
# Validation set results:
# Average case accuracy: 18024.0/19867.0=0.9072331190109253
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7549.0/8535.0=0.8844757080078125
#
# Test set results:
# Average case accuracy: 18506.0/19962.0=0.9270614385604858
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18309.0/19867.0=0.9215785264968872
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Test set results:
# Average case accuracy: 18622.0/19962.0=0.932872474193573
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 139.0/180.0=0.7722222208976746
#
# Validation set results:
# Average case accuracy: 18371.0/19867.0=0.9246992468833923
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/182.0=0.8351648449897766
#
# Test set results:
# Average case accuracy: 18403.0/19962.0=0.9219015836715698
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 148.0/180.0=0.8222222328186035
#
# Validation set results:
# Average case accuracy: 18166.0/19867.0=0.9143806099891663
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 17233.0/19962.0=0.8632902503013611
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8183.0/9767.0=0.8378212451934814
#
# Validation set results:
# Average case accuracy: 16869.0/19867.0=0.8490964770317078
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6813.0/8535.0=0.7982425093650818
#
# Test set results:
# Average case accuracy: 17480.0/19962.0=0.8756637573242188
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8270.0/9767.0=0.8467288017272949
#
# Validation set results:
# Average case accuracy: 17143.0/19867.0=0.8628882169723511
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6922.0/8535.0=0.8110134601593018
#
# Epoch 20: total loss 201.1581268310547 (with distillation) 70.04750168323517 (without distillation) in 89.42615175247192 seconds
# Test set results:
# Average case accuracy: 18111.0/19962.0=0.9072738289833069
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/180.0=0.8722222447395325
#
# Validation set results:
# Average case accuracy: 17791.0/19867.0=0.8955051302909851
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7415.0/8535.0=0.8687756061553955
#
# Test set results:
# Average case accuracy: 17749.0/19962.0=0.8891393542289734
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8567.0/9767.0=0.877137303352356
#
# Validation set results:
# Average case accuracy: 17380.0/19867.0=0.8748175501823425
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7208.0/8535.0=0.8445225358009338
#
# Test set results:
# Average case accuracy: 18140.0/19962.0=0.9087265729904175
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/180.0=0.8833333253860474
#
# Validation set results:
# Average case accuracy: 17817.0/19867.0=0.8968138098716736
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7512.0/8535.0=0.8801406025886536
#
# Test set results:
# Average case accuracy: 18454.0/19962.0=0.9244564771652222
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 150.0/180.0=0.8333333134651184
#
# Validation set results:
# Average case accuracy: 18218.0/19867.0=0.916998028755188
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/182.0=0.8571428656578064
#
# Test set results:
# Average case accuracy: 18077.0/19962.0=0.9055705666542053
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/180.0=0.8888888955116272
#
# Validation set results:
# Average case accuracy: 17720.0/19867.0=0.8919313549995422
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7432.0/8535.0=0.8707674145698547
#
# Test set results:
# Average case accuracy: 16713.0/19962.0=0.8372407555580139
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6131.0/7535.0=0.8136695623397827
#
# Validation set results:
# Average case accuracy: 16296.0/19867.0=0.8202546834945679
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6594.0/8535.0=0.7725834846496582
#
# Test set results:
# Average case accuracy: 17002.0/19962.0=0.8517182469367981
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8054.0/9767.0=0.8246135115623474
#
# Validation set results:
# Average case accuracy: 16669.0/19867.0=0.8390295505523682
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6704.0/8535.0=0.7854715585708618
#
# Test set results:
# Average case accuracy: 18130.0/19962.0=0.9082256555557251
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17871.0/19867.0=0.899531900882721
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7419.0/8535.0=0.8692442774772644
#
# Test set results:
# Average case accuracy: 18287.0/19962.0=0.9160905480384827
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 163.0/180.0=0.9055555462837219
#
# Validation set results:
# Average case accuracy: 17943.0/19867.0=0.9031559824943542
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7555.0/8535.0=0.8851786851882935
#
# Test set results:
# Average case accuracy: 18746.0/19962.0=0.9390842318534851
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 125.0/180.0=0.6944444179534912
#
# Validation set results:
# Average case accuracy: 18572.0/19867.0=0.9348165392875671
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 137.0/182.0=0.7527472376823425
#
# Test set results:
# Average case accuracy: 17908.0/19962.0=0.8971045017242432
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6695.0/7535.0=0.8885202407836914
#
# Validation set results:
# Average case accuracy: 17559.0/19867.0=0.8838274478912354
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7315.0/8535.0=0.8570591807365417
#
# Test set results:
# Average case accuracy: 17931.0/19962.0=0.8982566595077515
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6699.0/7535.0=0.889051079750061
#
# Validation set results:
# Average case accuracy: 17560.0/19867.0=0.8838778138160706
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7319.0/8535.0=0.8575278520584106
#
# Test set results:
# Average case accuracy: 17172.0/19962.0=0.8602344393730164
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6316.0/7535.0=0.8382216095924377
#
# Validation set results:
# Average case accuracy: 16811.0/19867.0=0.8461771011352539
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6894.0/8535.0=0.807732880115509
#
# Test set results:
# Average case accuracy: 18525.0/19962.0=0.9280132055282593
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18268.0/19867.0=0.9195147752761841
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/182.0=0.8296703100204468
#
# Test set results:
# Average case accuracy: 18156.0/19962.0=0.9095280766487122
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/180.0=0.8722222447395325
#
# Validation set results:
# Average case accuracy: 17886.0/19867.0=0.9002869129180908
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7413.0/8535.0=0.8685413002967834
#
# Test set results:
# Average case accuracy: 17491.0/19962.0=0.8762148022651672
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8374.0/9767.0=0.8573768734931946
#
# Validation set results:
# Average case accuracy: 17139.0/19867.0=0.8626868724822998
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7001.0/8535.0=0.8202694654464722
#
# Test set results:
# Average case accuracy: 17580.0/19962.0=0.8806732892990112
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8410.0/9767.0=0.86106276512146
#
# Validation set results:
# Average case accuracy: 17245.0/19867.0=0.8680223226547241
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7044.0/8535.0=0.8253075480461121
#
# Test set results:
# Average case accuracy: 17877.0/19962.0=0.8955515623092651
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8612.0/9767.0=0.8817446231842041
#
# Validation set results:
# Average case accuracy: 17605.0/19867.0=0.8861428499221802
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7280.0/8535.0=0.8529583811759949
#
# Test set results:
# Average case accuracy: 18195.0/19962.0=0.9114817976951599
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17922.0/19867.0=0.9020989537239075
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7509.0/8535.0=0.8797891139984131
#
# Test set results:
# Average case accuracy: 18034.0/19962.0=0.9034165143966675
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6764.0/7535.0=0.897677481174469
#
# Validation set results:
# Average case accuracy: 17723.0/19867.0=0.8920823335647583
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7458.0/8535.0=0.8738136887550354
#
# Epoch 30: total loss 195.93874621391296 (with distillation) 66.8115786910057 (without distillation) in 92.96088361740112 seconds
# Test set results:
# Average case accuracy: 18447.0/19962.0=0.9241058230400085
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/180.0=0.8722222447395325
#
# Validation set results:
# Average case accuracy: 18183.0/19867.0=0.9152362942695618
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 162.0/182.0=0.8901098966598511
#
# Test set results:
# Average case accuracy: 18585.0/19962.0=0.9310189485549927
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18324.0/19867.0=0.9223335385322571
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 18188.0/19962.0=0.9111311435699463
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8790.0/9767.0=0.8999692797660828
#
# Validation set results:
# Average case accuracy: 17851.0/19867.0=0.8985251784324646
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7407.0/8535.0=0.8678383231163025
#
# Test set results:
# Average case accuracy: 18159.0/19962.0=0.9096783995628357
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/180.0=0.8833333253860474
#
# Validation set results:
# Average case accuracy: 17850.0/19867.0=0.8984748721122742
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7422.0/8535.0=0.8695957660675049
#
# Test set results:
# Average case accuracy: 17588.0/19962.0=0.8810740113258362
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8373.0/9767.0=0.8572744727134705
#
# Validation set results:
# Average case accuracy: 17219.0/19867.0=0.8667136430740356
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6984.0/8535.0=0.8182776570320129
#
# Test set results:
# Average case accuracy: 17821.0/19962.0=0.8927462100982666
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8531.0/9767.0=0.8734514117240906
#
# Validation set results:
# Average case accuracy: 17517.0/19867.0=0.8817133903503418
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7179.0/8535.0=0.8411247730255127
#
# Test set results:
# Average case accuracy: 18749.0/19962.0=0.9392345547676086
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 143.0/180.0=0.7944444417953491
#
# Validation set results:
# Average case accuracy: 18519.0/19867.0=0.932148814201355
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 18551.0/19962.0=0.9293156862258911
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 143.0/180.0=0.7944444417953491
#
# Validation set results:
# Average case accuracy: 18240.0/19867.0=0.91810542345047
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 150.0/182.0=0.8241758346557617
#
# Test set results:
# Average case accuracy: 18822.0/19962.0=0.9428914785385132
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 133.0/180.0=0.7388888597488403
#
# Validation set results:
# Average case accuracy: 18592.0/19867.0=0.9358232021331787
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 145.0/182.0=0.7967032790184021
#
# Test set results:
# Average case accuracy: 18427.0/19962.0=0.9231038689613342
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 149.0/180.0=0.8277778029441833
#
# Validation set results:
# Average case accuracy: 18150.0/19867.0=0.913575291633606
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/182.0=0.8791208863258362
#
# Test set results:
# Average case accuracy: 18244.0/19962.0=0.9139364957809448
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/180.0=0.8888888955116272
#
# Validation set results:
# Average case accuracy: 17964.0/19867.0=0.904213011264801
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7555.0/8535.0=0.8851786851882935
#
# Test set results:
# Average case accuracy: 16817.0/19962.0=0.8424506783485413
#
# Worst case group: male [spurious] and not blond_hair [target]
# Worst case accuracy: 6176.0/7535.0=0.819641649723053
#
# Validation set results:
# Average case accuracy: 16377.0/19867.0=0.8243318200111389
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6637.0/8535.0=0.7776215672492981
#
# Test set results:
# Average case accuracy: 18615.0/19962.0=0.9325218200683594
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18370.0/19867.0=0.9246489405632019
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Test set results:
# Average case accuracy: 18182.0/19962.0=0.910830557346344
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17895.0/19867.0=0.9007399082183838
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7395.0/8535.0=0.8664323091506958
#
# Test set results:
# Average case accuracy: 17978.0/19962.0=0.900611162185669
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8600.0/9767.0=0.8805160522460938
#
# Validation set results:
# Average case accuracy: 17694.0/19867.0=0.890622615814209
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7256.0/8535.0=0.850146472454071
#
# Test set results:
# Average case accuracy: 18531.0/19962.0=0.9283137917518616
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 144.0/180.0=0.800000011920929
#
# Validation set results:
# Average case accuracy: 18281.0/19867.0=0.9201691150665283
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/182.0=0.8296703100204468
#
# Test set results:
# Average case accuracy: 18638.0/19962.0=0.9336739778518677
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 18398.0/19867.0=0.926058292388916
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 154.0/182.0=0.8461538553237915
#
# Test set results:
# Average case accuracy: 18537.0/19962.0=0.9286143779754639
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18251.0/19867.0=0.9186590909957886
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/182.0=0.8571428656578064
#
# Test set results:
# Average case accuracy: 18598.0/19962.0=0.9316701889038086
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/180.0=0.8388888835906982
#
# Validation set results:
# Average case accuracy: 18334.0/19867.0=0.9228368401527405
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/182.0=0.8626373410224915
#
# Test set results:
# Average case accuracy: 18232.0/19962.0=0.9133353233337402
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 157.0/180.0=0.8722222447395325
#
# Validation set results:
# Average case accuracy: 17891.0/19867.0=0.9005385637283325
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7465.0/8535.0=0.8746338486671448
#
# Epoch 40: total loss 191.24735689163208 (with distillation) 61.683794021606445 (without distillation) in 94.35252141952515 seconds
# Test set results:
# Average case accuracy: 18599.0/19962.0=0.9317202568054199
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18298.0/19867.0=0.9210247993469238
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 150.0/182.0=0.8241758346557617
#
# Test set results:
# Average case accuracy: 18140.0/19962.0=0.9087265729904175
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17790.0/19867.0=0.8954547643661499
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7300.0/8535.0=0.8553016781806946
#
# Test set results:
# Average case accuracy: 18841.0/19962.0=0.9438433051109314
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 130.0/180.0=0.7222222089767456
#
# Validation set results:
# Average case accuracy: 18649.0/19867.0=0.9386923313140869
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 141.0/182.0=0.7747252583503723
#
# Test set results:
# Average case accuracy: 18845.0/19962.0=0.9440436959266663
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 120.0/180.0=0.6666666865348816
#
# Validation set results:
# Average case accuracy: 18634.0/19867.0=0.9379372596740723
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 130.0/182.0=0.7142857313156128
#
# Test set results:
# Average case accuracy: 17994.0/19962.0=0.9014126658439636
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8619.0/9767.0=0.8824613690376282
#
# Validation set results:
# Average case accuracy: 17698.0/19867.0=0.8908239603042603
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7290.0/8535.0=0.8541300296783447
#
# Test set results:
# Average case accuracy: 18266.0/19962.0=0.9150385856628418
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 158.0/180.0=0.8777777552604675
#
# Validation set results:
# Average case accuracy: 17963.0/19867.0=0.9041627049446106
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7464.0/8535.0=0.8745167255401611
#
# Test set results:
# Average case accuracy: 18415.0/19962.0=0.9225027561187744
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/180.0=0.8500000238418579
#
# Validation set results:
# Average case accuracy: 18148.0/19867.0=0.9134746193885803
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7582.0/8535.0=0.8883421421051025
#
# Test set results:
# Average case accuracy: 17796.0/19962.0=0.8914938569068909
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8624.0/9767.0=0.8829732537269592
#
# Validation set results:
# Average case accuracy: 17464.0/19867.0=0.8790456652641296
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7284.0/8535.0=0.8534270524978638
#
# Test set results:
# Average case accuracy: 18474.0/19962.0=0.9254583716392517
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 156.0/180.0=0.8666666746139526
#
# Validation set results:
# Average case accuracy: 18243.0/19867.0=0.918256402015686
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 164.0/182.0=0.901098906993866
#
# Test set results:
# Average case accuracy: 18369.0/19962.0=0.920198380947113
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 151.0/180.0=0.8388888835906982
#
# Validation set results:
# Average case accuracy: 18071.0/19867.0=0.9095988273620605
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 163.0/182.0=0.8956043720245361
#
# Test set results:
# Average case accuracy: 18065.0/19962.0=0.9049694538116455
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8749.0/9767.0=0.8957715034484863
#
# Validation set results:
# Average case accuracy: 17836.0/19867.0=0.8977701663970947
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7441.0/8535.0=0.8718218803405762
#
# Test set results:
# Average case accuracy: 17212.0/19962.0=0.8622382283210754
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8077.0/9767.0=0.8269683718681335
#
# Validation set results:
# Average case accuracy: 16875.0/19867.0=0.8493984937667847
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 6746.0/8535.0=0.7903925180435181
#
# Test set results:
# Average case accuracy: 17920.0/19962.0=0.897705614566803
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 8544.0/9767.0=0.8747824430465698
#
# Validation set results:
# Average case accuracy: 17568.0/19867.0=0.8842804431915283
#
# Worst case group: not male [spurious] and not blond_hair [target]
# Worst case accuracy: 7191.0/8535.0=0.8425307273864746
#
# Test set results:
# Average case accuracy: 18689.0/19962.0=0.9362288117408752
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 142.0/180.0=0.7888888716697693
#
# Validation set results:
# Average case accuracy: 18418.0/19867.0=0.9270649552345276
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/182.0=0.8351648449897766
#
# Test set results:
# Average case accuracy: 18479.0/19962.0=0.9257088303565979
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 153.0/180.0=0.8500000238418579
#
# Validation set results:
# Average case accuracy: 18219.0/19867.0=0.9170483946800232
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 160.0/182.0=0.8791208863258362
#
# Test set results:
# Average case accuracy: 18446.0/19962.0=0.9240556955337524
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 147.0/180.0=0.8166666626930237
#
# Validation set results:
# Average case accuracy: 18212.0/19867.0=0.9166960120201111
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/182.0=0.8736263513565063
#
# Test set results:
# Average case accuracy: 18600.0/19962.0=0.931770384311676
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 146.0/180.0=0.8111110925674438
#
# Validation set results:
# Average case accuracy: 18358.0/19867.0=0.9240449070930481
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 155.0/182.0=0.8516483306884766
#
# Test set results:
# Average case accuracy: 18631.0/19962.0=0.933323323726654
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 136.0/180.0=0.7555555701255798
#
# Validation set results:
# Average case accuracy: 18427.0/19867.0=0.9275180101394653
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 154.0/182.0=0.8461538553237915
#
# Test set results:
# Average case accuracy: 18496.0/19962.0=0.9265604615211487
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 152.0/180.0=0.8444444537162781
#
# Validation set results:
# Average case accuracy: 18301.0/19867.0=0.9211758375167847
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 159.0/182.0=0.8736263513565063
#
# Test set results:
# Average case accuracy: 18831.0/19962.0=0.9433423280715942
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 119.0/180.0=0.6611111164093018
#
# Validation set results:
# Average case accuracy: 18643.0/19867.0=0.93839031457901
#
# Worst case group: male [spurious] and blond_hair [target]
# Worst case accuracy: 136.0/182.0=0.7472527623176575
#
# Epoch 50: total loss 185.52128159999847 (with distillation) 58.974413216114044 (without distillation) in 94.11593747138977 seconds
